# %%
from pathlib import Path

import pandas as pd

# %%
df_results = pd.DataFrame()
for i in range(40):
    path_results = f"{i}_results_gdsearch.json.gz"
    df_results = pd.concat(
        [df_results, pd.read_json(path_results, orient="index")], axis=0
    )
print(df_results.shape)
display(df_results.head())
# Out:
# (360000, 5)
#                                              hparams        mae       rmse  \
# 0  {'max_depth': 4, 'min_samples_leaf': 0.0001, '...  10.387298  18.446285
# 1  {'max_depth': 4, 'min_samples_leaf': 0.0001, '...  10.358007  18.442013
# 2  {'max_depth': 4, 'min_samples_leaf': 0.0001, '...  10.341153  18.504365
# 3  {'max_depth': 4, 'min_samples_leaf': 0.0001, '...  10.346316  18.508845
# 4  {'max_depth': 4, 'min_samples_leaf': 0.0001, '...  10.348982  18.507664
#
#    spearman  r2_score
# 0  0.763764  0.538816
# 1  0.763721  0.539029
# 2  0.764064  0.535907
# 3  0.765563  0.535682
# 4  0.765836  0.535742

# %%
for metric, ascending in zip(
    ["mae", "rmse", "spearman", "r2_score"], [True, True, False, False]
):
    display(df_results.sort_values(by=metric, ascending=ascending).iloc[:5])
# Out:
#                                                   hparams       mae  \
# 270005  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...  9.375753
# 270023  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...  9.382702
# 270021  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...  9.390897
# 270008  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...  9.395575
# 270026  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...  9.397365
#
#              rmse  spearman  r2_score
# 270005  18.273828  0.798937  0.547399
# 270023  18.000809  0.798341  0.560822
# 270021  17.963144  0.799355  0.562658
# 270008  18.441396  0.798900  0.539060
# 270026  18.082755  0.799803  0.556814
#                                                   hparams        mae  \
# 270021  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...   9.390897
# 270023  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...   9.382702
# 270022  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...   9.405609
# 90036   {'max_depth': 6, 'min_samples_leaf': 0.0001, '...  10.013795
# 270024  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...   9.409249
#
#              rmse  spearman  r2_score
# 270021  17.963144  0.799355  0.562658
# 270023  18.000809  0.798341  0.560822
# 270022  18.004339  0.798531  0.560650
# 90036   18.058839  0.774759  0.557986
# 270024  18.074406  0.798323  0.557223
#                                                   hparams       mae  \
# 270910  {'max_depth': 10, 'min_samples_leaf': 0.005098...  9.633704
# 270901  {'max_depth': 10, 'min_samples_leaf': 0.005098...  9.633704
# 270919  {'max_depth': 10, 'min_samples_leaf': 0.005098...  9.633704
# 270911  {'max_depth': 10, 'min_samples_leaf': 0.005098...  9.591151
# 270902  {'max_depth': 10, 'min_samples_leaf': 0.005098...  9.591151
#
#              rmse  spearman  r2_score
# 270910  19.069606  0.825210  0.507121
# 270901  19.069606  0.825210  0.507121
# 270919  19.069606  0.825210  0.507121
# 270911  19.080222  0.824233  0.506572
# 270902  19.080222  0.824233  0.506572
#                                                   hparams        mae  \
# 270021  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...   9.390897
# 270023  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...   9.382702
# 270022  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...   9.405609
# 90036   {'max_depth': 6, 'min_samples_leaf': 0.0001, '...  10.013795
# 270024  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...   9.409249
#
#              rmse  spearman  r2_score
# 270021  17.963144  0.799355  0.562658
# 270023  18.000809  0.798341  0.560822
# 270022  18.004339  0.798531  0.560650
# 90036   18.058839  0.774759  0.557986
# 270024  18.074406  0.798323  0.557223

# %%
index_opti = 270023
hparams_opti = df_results.loc[index_opti]["hparams"]
hparams_opti.pop("n_jobs")
hparams_opti
# Out:
# {'max_depth': 10,
#  'min_samples_leaf': 0.0001,
#  'min_samples_split': 0.010098,
#  'n_estimators': 350,
#  'random_state': 42}

# %%
path_hparams_opti = "hparams_opti.json"
df_hparams_opti = pd.DataFrame.from_dict(hparams_opti, orient="index")
if not Path(path_hparams_opti).exists():
    df_hparams_opti.to_json(path_hparams_opti)

pd.read_json(path_hparams_opti).to_dict()[0]
# Out:
# {'max_depth': 10.0,
#  'min_samples_leaf': 0.0001,
#  'min_samples_split': 0.010098,
#  'n_estimators': 350.0,
#  'random_state': 42.0}
