# %%
from pathlib import Path

import pandas as pd

# %%
df_results = pd.DataFrame()
for i in range(40):
    path_results = f"{i}_results_gdsearch.json.gz"
    df_results = pd.concat(
        [df_results, pd.read_json(path_results, orient="index")], axis=0
    )
print(df_results.shape)
display(df_results.head())
# Out:
# (360000, 5)
#                                              hparams        mae       rmse  \
# 0  {'max_depth': 4, 'min_samples_leaf': 0.0001, '...  10.138805  18.638087
# 1  {'max_depth': 4, 'min_samples_leaf': 0.0001, '...  10.132457  18.634586
# 2  {'max_depth': 4, 'min_samples_leaf': 0.0001, '...  10.152295  18.702680
# 3  {'max_depth': 4, 'min_samples_leaf': 0.0001, '...  10.177881  18.745545
# 4  {'max_depth': 4, 'min_samples_leaf': 0.0001, '...  10.204231  18.805090
#
#    spearman  r2_score
# 0  0.788293  0.592062
# 1  0.789478  0.592215
# 2  0.789611  0.589229
# 3  0.789507  0.587344
# 4  0.789860  0.584718

# %%
for metric, ascending in zip(
    ["mae", "rmse", "spearman", "r2_score"], [True, True, False, False]
):
    display(df_results.sort_values(by=metric, ascending=ascending).iloc[:5])
# Out:
#                                                   hparams       mae  \
# 270000  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...  8.836629
# 270002  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...  8.898053
# 270001  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...  8.920600
# 270003  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...  8.920687
# 270004  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...  8.923166
#
#              rmse  spearman  r2_score
# 270000  16.888139  0.822736  0.665069
# 270002  16.982033  0.822079  0.661334
# 270001  17.025929  0.821442  0.659581
# 270003  16.992440  0.823942  0.660919
# 270004  16.993056  0.821895  0.660895
#                                                   hparams       mae  \
# 270017  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...  8.948284
# 270016  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...  8.953562
# 270015  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...  8.975244
# 270014  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...  8.974472
# 270000  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...  8.836629
#
#              rmse  spearman  r2_score
# 270017  16.822878  0.821683  0.667653
# 270016  16.838573  0.821759  0.667032
# 270015  16.859288  0.822742  0.666212
# 270014  16.877926  0.822234  0.665474
# 270000  16.888139  0.822736  0.665069
#                                                   hparams       mae  \
# 270926  {'max_depth': 10, 'min_samples_leaf': 0.005098...  9.093212
# 270917  {'max_depth': 10, 'min_samples_leaf': 0.005098...  9.093212
# 270908  {'max_depth': 10, 'min_samples_leaf': 0.005098...  9.093212
# 270924  {'max_depth': 10, 'min_samples_leaf': 0.005098...  9.070549
# 270906  {'max_depth': 10, 'min_samples_leaf': 0.005098...  9.070549
#
#              rmse  spearman  r2_score
# 270926  17.726738  0.835889  0.630980
# 270917  17.726738  0.835889  0.630980
# 270908  17.726738  0.835889  0.630980
# 270924  17.698396  0.835762  0.632159
# 270906  17.698396  0.835762  0.632159
#                                                   hparams       mae  \
# 270017  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...  8.948284
# 270016  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...  8.953562
# 270015  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...  8.975244
# 270014  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...  8.974472
# 270000  {'max_depth': 10, 'min_samples_leaf': 0.0001, ...  8.836629
#
#              rmse  spearman  r2_score
# 270017  16.822878  0.821683  0.667653
# 270016  16.838573  0.821759  0.667032
# 270015  16.859288  0.822742  0.666212
# 270014  16.877926  0.822234  0.665474
# 270000  16.888139  0.822736  0.665069

# %%
index_opti = 270000
hparams_opti = df_results.loc[index_opti]["hparams"]
hparams_opti.pop("n_jobs")
hparams_opti
# Out:
# {'max_depth': 10,
#  'min_samples_leaf': 0.0001,
#  'min_samples_split': 0.0001,
#  'n_estimators': 100,
#  'random_state': 42}

# %%
path_hparams_opti = "hparams_opti.json"
df_hparams_opti = pd.DataFrame.from_dict(hparams_opti, orient="index")
if not Path(path_hparams_opti).exists():
    df_hparams_opti.to_json(path_hparams_opti)

pd.read_json(path_hparams_opti).to_dict()[0]
# Out:
# {'max_depth': 10.0,
#  'min_samples_leaf': 0.0001,
#  'min_samples_split': 0.0001,
#  'n_estimators': 100.0,
#  'random_state': 42.0}
