# %%
from pathlib import Path

import pandas as pd

# %%
df_results = pd.DataFrame()
for i in range(40):
    path_results = f"{i}_results_gdsearch.json.gz"
    df_results = pd.concat(
        [df_results, pd.read_json(path_results, orient="index")], axis=0
    )
print(df_results.shape)
display(df_results.head())
# Out:
# (195000, 5)
#                                              hparams       mae       rmse  \
# 0  {'learning_rate': 0.05, 'max_depth': 2, 'min_c...  8.833888  16.553244
# 1  {'learning_rate': 0.05, 'max_depth': 2, 'min_c...  8.833888  16.553244
# 2  {'learning_rate': 0.05, 'max_depth': 2, 'min_c...  8.833888  16.553244
# 3  {'learning_rate': 0.05, 'max_depth': 2, 'min_c...  8.833888  16.553244
# 4  {'learning_rate': 0.05, 'max_depth': 2, 'min_c...  8.833888  16.553244
#
#    spearman  r2_score
# 0  0.732802  0.623839
# 1  0.732802  0.623839
# 2  0.732802  0.623839
# 3  0.732802  0.623839
# 4  0.732802  0.623839

# %%
for metric, ascending in zip(
    ["mae", "rmse", "spearman", "r2_score"], [True, True, False, False]
):
    display(df_results.sort_values(by=metric, ascending=ascending).iloc[:5])
# Out:
#                                                  hparams       mae       rmse  \
# 50510  {'learning_rate': 0.16363636363636302, 'max_de...  4.657111  11.139632
# 93406  {'learning_rate': 0.263636363636363, 'max_dept...  4.698091  10.321058
# 93016  {'learning_rate': 0.263636363636363, 'max_dept...  4.698091  10.321058
# 92821  {'learning_rate': 0.263636363636363, 'max_dept...  4.698091  10.321058
# 93211  {'learning_rate': 0.263636363636363, 'max_dept...  4.698091  10.321058
#
#        spearman  r2_score
# 50510  0.848713  0.829647
# 93406  0.835343  0.853764
# 93016  0.835343  0.853764
# 92821  0.835343  0.853764
# 93211  0.835343  0.853764
#                                                   hparams       mae      rmse  \
# 185071  {'learning_rate': 0.477272727272727, 'max_dept...  5.007049  9.333808
# 184486  {'learning_rate': 0.477272727272727, 'max_dept...  5.007049  9.333808
# 184876  {'learning_rate': 0.477272727272727, 'max_dept...  5.007049  9.333808
# 184681  {'learning_rate': 0.477272727272727, 'max_dept...  5.007049  9.333808
# 184291  {'learning_rate': 0.477272727272727, 'max_dept...  5.061177  9.592916
#
#         spearman  r2_score
# 185071  0.758685  0.880402
# 184486  0.758685  0.880402
# 184876  0.758685  0.880402
# 184681  0.758685  0.880402
# 184291  0.758347  0.873669
#                                                  hparams       mae       rmse  \
# 63792  {'learning_rate': 0.19545454545454502, 'max_de...  5.475854  13.175760
# 81343  {'learning_rate': 0.23636363636363603, 'max_de...  5.686335  13.279364
# 47810  {'learning_rate': 0.159090909090909, 'max_dept...  5.479169  12.772492
# 36275  {'learning_rate': 0.131818181818181, 'max_dept...  5.392077  12.795511
# 42549  {'learning_rate': 0.145454545454545, 'max_dept...  5.636571  13.205511
#
#        spearman  r2_score
# 63792  0.883699  0.761681
# 81343  0.881911  0.757918
# 47810  0.880135  0.776046
# 36275  0.875969  0.775238
# 42549  0.875250  0.760604
#                                                   hparams       mae      rmse  \
# 184486  {'learning_rate': 0.477272727272727, 'max_dept...  5.007049  9.333808
# 184876  {'learning_rate': 0.477272727272727, 'max_dept...  5.007049  9.333808
# 185071  {'learning_rate': 0.477272727272727, 'max_dept...  5.007049  9.333808
# 184681  {'learning_rate': 0.477272727272727, 'max_dept...  5.007049  9.333808
# 184291  {'learning_rate': 0.477272727272727, 'max_dept...  5.061177  9.592916
#
#         spearman  r2_score
# 184486  0.758685  0.880402
# 184876  0.758685  0.880402
# 185071  0.758685  0.880402
# 184681  0.758685  0.880402
# 184291  0.758347  0.873669

# %%
index_opti = 47810
hparams_opti = df_results.loc[index_opti]["hparams"]
hparams_opti.pop("n_jobs")
hparams_opti
# Out:
# {'learning_rate': 0.159090909090909,
#  'max_depth': 12,
#  'min_child_samples': 10,
#  'num_leaves': 60,
#  'random_state': 42}

# %%
path_hparams_opti = "hparams_opti.json"
df_hparams_opti = pd.DataFrame.from_dict(hparams_opti, orient="index")
if not Path(path_hparams_opti).exists():
    df_hparams_opti.to_json(path_hparams_opti)

pd.read_json(path_hparams_opti).to_dict()[0]
# Out:
# {'learning_rate': 0.1590909091,
#  'max_depth': 12.0,
#  'min_child_samples': 10.0,
#  'num_leaves': 60.0,
#  'random_state': 42.0}
