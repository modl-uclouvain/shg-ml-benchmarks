# %%
from pathlib import Path

import pandas as pd

# %%
df_results = pd.DataFrame()
for i in range(40):
    path_results = f"{i}_results_gdsearch.json.gz"
    df_results = pd.concat(
        [df_results, pd.read_json(path_results, orient="index")], axis=0
    )
print(df_results.shape)
display(df_results.head())
# Out:
# (195000, 5)
#                                              hparams        mae       rmse  \
# 0  {'learning_rate': 0.05, 'max_depth': 2, 'min_c...  10.067401  19.742686
# 1  {'learning_rate': 0.05, 'max_depth': 2, 'min_c...  10.067401  19.742686
# 2  {'learning_rate': 0.05, 'max_depth': 2, 'min_c...  10.067401  19.742686
# 3  {'learning_rate': 0.05, 'max_depth': 2, 'min_c...  10.067401  19.742686
# 4  {'learning_rate': 0.05, 'max_depth': 2, 'min_c...  10.067401  19.742686
#
#    spearman  r2_score
# 0  0.791774  0.530998
# 1  0.791774  0.530998
# 2  0.791774  0.530998
# 3  0.791774  0.530998
# 4  0.791774  0.530998

# %%
for metric, ascending in zip(
    ["mae", "rmse", "spearman", "r2_score"], [True, True, False, False]
):
    display(df_results.sort_values(by=metric, ascending=ascending).iloc[:10])
# Out:
#                                                  hparams       mae       rmse  \
# 75857  {'learning_rate': 0.22272727272727202, 'max_de...  6.736798  14.874430
# 75662  {'learning_rate': 0.22272727272727202, 'max_de...  6.736798  14.874430
# 78781  {'learning_rate': 0.231818181818181, 'max_dept...  6.771881  14.227272
# 12287  {'learning_rate': 0.07727272727272701, 'max_de...  6.783717  14.560603
# 34322  {'learning_rate': 0.127272727272727, 'max_dept...  6.812801  14.938441
# 51301  {'learning_rate': 0.16818181818181802, 'max_de...  6.815651  14.437244
# 16774  {'learning_rate': 0.086363636363636, 'max_dept...  6.830521  15.049253
# 26328  {'learning_rate': 0.109090909090909, 'max_dept...  6.836051  14.759019
# 82486  {'learning_rate': 0.24090909090909002, 'max_de...  6.836065  15.424327
# 80341  {'learning_rate': 0.23636363636363603, 'max_de...  6.840894  13.966302
#
#        spearman  r2_score
# 75857  0.875023  0.733779
# 75662  0.875023  0.733779
# 78781  0.854001  0.756440
# 12287  0.872218  0.744894
# 34322  0.875221  0.731482
# 51301  0.878727  0.749198
# 16774  0.888779  0.727484
# 26328  0.880363  0.737894
# 82486  0.848304  0.713731
# 80341  0.835321  0.765294
#                                                   hparams       mae  \
# 76441   {'learning_rate': 0.22727272727272702, 'max_de...  6.886637
# 80341   {'learning_rate': 0.23636363636363603, 'max_de...  6.840894
# 92236   {'learning_rate': 0.263636363636363, 'max_dept...  6.953033
# 95941   {'learning_rate': 0.27272727272727204, 'max_de...  7.073779
# 74491   {'learning_rate': 0.22272727272727202, 'max_de...  6.981227
# 144692  {'learning_rate': 0.386363636363636, 'max_dept...  7.174957
# 78391   {'learning_rate': 0.231818181818181, 'max_dept...  7.113860
# 158146  {'learning_rate': 0.41818181818181804, 'max_de...  7.483918
# 158151  {'learning_rate': 0.41818181818181804, 'max_de...  7.483918
# 158150  {'learning_rate': 0.41818181818181804, 'max_de...  7.483918
#
#              rmse  spearman  r2_score
# 76441   13.863274  0.863412  0.768744
# 80341   13.966302  0.835321  0.765294
# 92236   14.045305  0.851466  0.762631
# 95941   14.081760  0.847919  0.761397
# 74491   14.103639  0.851777  0.760655
# 144692  14.210677  0.824731  0.757008
# 78391   14.213947  0.847564  0.756896
# 158146  14.221700  0.776366  0.756631
# 158151  14.221700  0.776366  0.756631
# 158150  14.221700  0.776366  0.756631
#                                                  hparams       mae       rmse  \
# 18335  {'learning_rate': 0.09090909090909001, 'max_de...  7.588944  16.818802
# 9378   {'learning_rate': 0.06818181818181801, 'max_de...  7.130437  15.309748
# 44658  {'learning_rate': 0.15, 'max_depth': 20, 'min_...  7.246256  15.420156
# 3708   {'learning_rate': 0.054545454545454, 'max_dept...  7.271383  15.452999
# 8598   {'learning_rate': 0.06818181818181801, 'max_de...  7.576111  15.752487
# 28670  {'learning_rate': 0.11363636363636301, 'max_de...  7.450967  16.064001
# 40370  {'learning_rate': 0.14090909090909, 'max_depth...  7.592697  16.203526
# 12484  {'learning_rate': 0.07727272727272701, 'max_de...  7.263923  15.557047
# 8778   {'learning_rate': 0.06818181818181801, 'max_de...  7.075121  14.974059
# 18137  {'learning_rate': 0.09090909090909001, 'max_de...  7.141765  15.011379
#
#        spearman  r2_score
# 18335  0.895867  0.659629
# 9378   0.894497  0.717968
# 44658  0.894331  0.713886
# 3708   0.892878  0.712666
# 8598   0.892191  0.701420
# 28670  0.892081  0.689494
# 40370  0.891673  0.684077
# 12484  0.891616  0.708783
# 8778   0.891426  0.730200
# 18137  0.891286  0.728854
#                                                   hparams       mae  \
# 76441   {'learning_rate': 0.22727272727272702, 'max_de...  6.886637
# 80341   {'learning_rate': 0.23636363636363603, 'max_de...  6.840894
# 92236   {'learning_rate': 0.263636363636363, 'max_dept...  6.953033
# 95941   {'learning_rate': 0.27272727272727204, 'max_de...  7.073779
# 74491   {'learning_rate': 0.22272727272727202, 'max_de...  6.981227
# 144692  {'learning_rate': 0.386363636363636, 'max_dept...  7.174957
# 78391   {'learning_rate': 0.231818181818181, 'max_dept...  7.113860
# 158157  {'learning_rate': 0.41818181818181804, 'max_de...  7.483918
# 158159  {'learning_rate': 0.41818181818181804, 'max_de...  7.483918
# 158158  {'learning_rate': 0.41818181818181804, 'max_de...  7.483918
#
#              rmse  spearman  r2_score
# 76441   13.863274  0.863412  0.768744
# 80341   13.966302  0.835321  0.765294
# 92236   14.045305  0.851466  0.762631
# 95941   14.081760  0.847919  0.761397
# 74491   14.103639  0.851777  0.760655
# 144692  14.210677  0.824731  0.757008
# 78391   14.213947  0.847564  0.756896
# 158157  14.221700  0.776366  0.756631
# 158159  14.221700  0.776366  0.756631
# 158158  14.221700  0.776366  0.756631

# %%
index_opti = 8778
hparams_opti = df_results.loc[index_opti]["hparams"]
hparams_opti.pop("n_jobs")
hparams_opti
# Out:
# {'learning_rate': 0.06818181818181801,
#  'max_depth': 12,
#  'min_child_samples': 6,
#  'num_leaves': 40,
#  'random_state': 42}

# %%
path_hparams_opti = "hparams_opti.json"
df_hparams_opti = pd.DataFrame.from_dict(hparams_opti, orient="index")
if not Path(path_hparams_opti).exists():
    df_hparams_opti.to_json(path_hparams_opti)

pd.read_json(path_hparams_opti).to_dict()[0]
# Out:
# {'learning_rate': 0.06818181820000001,
#  'max_depth': 12.0,
#  'min_child_samples': 6.0,
#  'num_leaves': 40.0,
#  'random_state': 42.0}
