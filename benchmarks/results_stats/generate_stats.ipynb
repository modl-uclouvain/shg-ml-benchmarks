# %%
from collections import Counter
from pathlib import Path

import json
import os
import pandas as pd

# %%
# 1. Lists all directories in the previous dir
# 2. Create a dict with the name of the models as keys
# 3. The values will be a new dict with the denomination of the "tasks_..." or "tasks" dir as key
# 4. The values of this last dict will be a new dict with the task (or split) as key so random_125 for example
# 5. The values of this last dict will be a new dict with the type of features (mmf e.g.) as key
# 6. The values of this last dict will be a new dict with the name of the metric as key
# 7. The values of this last dict will be the metric itself

# %%
# 1. Lists all directories in the previous dir
path_benchmarks = Path("..")
model_names = next(os.walk(path_benchmarks), (None, None, []))[1]
model_names.remove("results_stats")
model_names
# Out:
# ['matten', 'modnet', 'mean_value', 'et']

# %%
# 2. Create a dict with the name of the models as keys
dict_results = {m: {} for m in model_names}
dict_results
# Out:
# {'matten': {}, 'modnet': {}, 'mean_value': {}, 'et': {}}

# %%
# 3. The values will be a new dict with the denomination of the "tasks_..." or "tasks" dir as key
for m in dict_results.keys():
    path_tasks = path_benchmarks / m
    for d in next(os.walk(path_tasks), (None, None, []))[1]:
        if "tasks" in d:
            dict_results[m].update({d: {}})

print(dict_results)
# Out:
# {'matten': {}, 'modnet': {'tasks': {}}, 'mean_value': {'tasks': {}}, 'et': {'tasks_dflt': {}, 'tasks_An': {}}}

# %%
# 4. The values of this last dict will be a new dict with the task (or split) as key so random_125 for example
for m in dict_results.keys():
    path_tasks = path_benchmarks / m
    for t in dict_results[m].keys():
        path_split = path_tasks / t
        for d in next(os.walk(path_split), (None, None, []))[1]:
            if "distribution" in d or "random" in d:
                dict_results[m][t].update({d: {}})

print(dict_results)
# Out:
# {'matten': {}, 'modnet': {'tasks': {'distribution_125': {}, 'distribution_250': {}, 'random_125': {}, 'random_250': {}}}, 'mean_value': {'tasks': {'random_250': {}}}, 'et': {'tasks_dflt': {'distribution_125': {}, 'distribution_250': {}, 'random_125': {}, 'random_250': {}}, 'tasks_An': {'distribution_125': {}, 'distribution_250': {}, 'random_125': {}, 'random_250': {}}}}

# %%
# 5. The values of this last dict will be a new dict with the type of features (mmf e.g.) as key
for m in dict_results.keys():
    path_tasks = path_benchmarks / m
    for t in dict_results[m].keys():
        path_split = path_tasks / t
        for s in dict_results[m][t].keys():
            path_feat = path_split / s

            for f in next(os.walk(path_feat), (None, None, []))[2]:
                if "json" not in f:
                    continue
                path_results = path_feat / f
                with open(path_results, 'r') as file:
                    results = json.load(file)
                dict_results[m][t][s].update({f.split(".json")[0]: results['metrics']})

# display(dict_results)

# %%
f = {}
stack = [(dict_results, '')]  # Stack holds tuples of (current_dict, current_key)

while stack:
    c, p = stack.pop()
    
    for k, v in c.items():
        new_key = f"{p}_{k}" if p else k
        
        if isinstance(v, dict):
            stack.append((v, new_key))  # Push the nested dictionary onto the stack
        else:
            f[new_key] = v  # Add to the flattened dictionary

# print(f)

# %%
dict_results_ravel = {}
for k, v in f.items():
    new_k, metric = k.replace("_tasks","").split("results_")
    if new_k not in dict_results_ravel.keys():
        dict_results_ravel[new_k] = {}
    dict_results_ravel[new_k][metric] = v

# %%
def df_style(val):
    return "color: red"
def df_style_bold(val):
    return "font-weight: bold"
import numpy as np
def highlight_max(s, props='color:red'):
    return np.where(s == np.nanmax(s.values), props, '')

df_results = pd.DataFrame.from_dict(dict_results_ravel, orient="index")

dict_df_results_splits = {}
for split in ["random_125", "random_250", "distribution_125", "distribution_250"]:
    indexes = []
    for i in df_results.index:
        if split in i:
            indexes.append(i)
    df_tmp = df_results.filter(indexes, axis=0)


    # and apply styling to it via the `subset` arg; first arg is styler function above
    idx_best = []
    idx_best.extend(df_tmp[['mae', 'rmse']].idxmin().tolist())
    idx_best.extend(df_tmp[['spearman', 'r2_score']].idxmax().tolist())
    df_tmp = df_tmp.style.applymap(df_style, subset=(idx_best, ["mae", "rmse", "spearman", "r2_score"]))

    idx_best_max, idx_best_max_count = Counter(idx_best).most_common(1)[0]
    if idx_best_max_count > 1:
        df_tmp = df_tmp.applymap(df_style_bold, subset=([idx_best_max], ["mae", "rmse", "spearman", "r2_score"]))

    dict_df_results_splits[split] = df_tmp

    print(split)
    display(dict_df_results_splits[split])
# Out:
# random_125
# <style type="text/css">
# #T_a5ae2_row8_col0, #T_a5ae2_row8_col1, #T_a5ae2_row8_col2, #T_a5ae2_row8_col3 {
#   color: red;
#   color: red;
#   color: red;
#   color: red;
#   font-weight: bold;
# }
# </style>
# <table id="T_a5ae2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5ae2_level0_col0" class="col_heading level0 col0" >mae</th>
#       <th id="T_a5ae2_level0_col1" class="col_heading level0 col1" >rmse</th>
#       <th id="T_a5ae2_level0_col2" class="col_heading level0 col2" >spearman</th>
#       <th id="T_a5ae2_level0_col3" class="col_heading level0 col3" >r2_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5ae2_level0_row0" class="row_heading level0 row0" >et_An_random_125_pgnn_</th>
#       <td id="T_a5ae2_row0_col0" class="data row0 col0" >8.647093</td>
#       <td id="T_a5ae2_row0_col1" class="data row0 col1" >20.012587</td>
#       <td id="T_a5ae2_row0_col2" class="data row0 col2" >0.886495</td>
#       <td id="T_a5ae2_row0_col3" class="data row0 col3" >0.575846</td>
#     </tr>
#     <tr>
#       <th id="T_a5ae2_level0_row1" class="row_heading level0 row1" >et_An_random_125_mmf_</th>
#       <td id="T_a5ae2_row1_col0" class="data row1 col0" >8.647552</td>
#       <td id="T_a5ae2_row1_col1" class="data row1 col1" >19.931938</td>
#       <td id="T_a5ae2_row1_col2" class="data row1 col2" >0.882402</td>
#       <td id="T_a5ae2_row1_col3" class="data row1 col3" >0.579258</td>
#     </tr>
#     <tr>
#       <th id="T_a5ae2_level0_row2" class="row_heading level0 row2" >et_An_random_125_mmf_pgnn_</th>
#       <td id="T_a5ae2_row2_col0" class="data row2 col0" >8.537435</td>
#       <td id="T_a5ae2_row2_col1" class="data row2 col1" >19.984474</td>
#       <td id="T_a5ae2_row2_col2" class="data row2 col2" >0.877677</td>
#       <td id="T_a5ae2_row2_col3" class="data row2 col3" >0.577037</td>
#     </tr>
#     <tr>
#       <th id="T_a5ae2_level0_row3" class="row_heading level0 row3" >et_dflt_random_125_pgnn_</th>
#       <td id="T_a5ae2_row3_col0" class="data row3 col0" >8.341509</td>
#       <td id="T_a5ae2_row3_col1" class="data row3 col1" >19.831881</td>
#       <td id="T_a5ae2_row3_col2" class="data row3 col2" >0.889002</td>
#       <td id="T_a5ae2_row3_col3" class="data row3 col3" >0.583472</td>
#     </tr>
#     <tr>
#       <th id="T_a5ae2_level0_row4" class="row_heading level0 row4" >et_dflt_random_125_mmf_</th>
#       <td id="T_a5ae2_row4_col0" class="data row4 col0" >8.192585</td>
#       <td id="T_a5ae2_row4_col1" class="data row4 col1" >19.784299</td>
#       <td id="T_a5ae2_row4_col2" class="data row4 col2" >0.892774</td>
#       <td id="T_a5ae2_row4_col3" class="data row4 col3" >0.585468</td>
#     </tr>
#     <tr>
#       <th id="T_a5ae2_level0_row5" class="row_heading level0 row5" >et_dflt_random_125_mmf_pgnn_</th>
#       <td id="T_a5ae2_row5_col0" class="data row5 col0" >8.307911</td>
#       <td id="T_a5ae2_row5_col1" class="data row5 col1" >19.589507</td>
#       <td id="T_a5ae2_row5_col2" class="data row5 col2" >0.894224</td>
#       <td id="T_a5ae2_row5_col3" class="data row5 col3" >0.593591</td>
#     </tr>
#     <tr>
#       <th id="T_a5ae2_level0_row6" class="row_heading level0 row6" >modnet_random_125_pgnn_</th>
#       <td id="T_a5ae2_row6_col0" class="data row6 col0" >8.262533</td>
#       <td id="T_a5ae2_row6_col1" class="data row6 col1" >19.751812</td>
#       <td id="T_a5ae2_row6_col2" class="data row6 col2" >0.901475</td>
#       <td id="T_a5ae2_row6_col3" class="data row6 col3" >0.586828</td>
#     </tr>
#     <tr>
#       <th id="T_a5ae2_level0_row7" class="row_heading level0 row7" >modnet_random_125_mmf_</th>
#       <td id="T_a5ae2_row7_col0" class="data row7 col0" >8.803178</td>
#       <td id="T_a5ae2_row7_col1" class="data row7 col1" >23.035541</td>
#       <td id="T_a5ae2_row7_col2" class="data row7 col2" >0.907785</td>
#       <td id="T_a5ae2_row7_col3" class="data row7 col3" >0.438029</td>
#     </tr>
#     <tr>
#       <th id="T_a5ae2_level0_row8" class="row_heading level0 row8" >modnet_random_125_mmf_pgnn_</th>
#       <td id="T_a5ae2_row8_col0" class="data row8 col0" >7.304253</td>
#       <td id="T_a5ae2_row8_col1" class="data row8 col1" >19.423989</td>
#       <td id="T_a5ae2_row8_col2" class="data row8 col2" >0.916129</td>
#       <td id="T_a5ae2_row8_col3" class="data row8 col3" >0.600429</td>
#     </tr>
#   </tbody>
# </table>
# random_250
# <style type="text/css">
# #T_af410_row4_col0, #T_af410_row4_col1, #T_af410_row4_col2, #T_af410_row4_col3 {
#   color: red;
#   color: red;
#   color: red;
#   font-weight: bold;
# }
# #T_af410_row9_col0, #T_af410_row9_col1, #T_af410_row9_col2, #T_af410_row9_col3 {
#   color: red;
# }
# </style>
# <table id="T_af410">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af410_level0_col0" class="col_heading level0 col0" >mae</th>
#       <th id="T_af410_level0_col1" class="col_heading level0 col1" >rmse</th>
#       <th id="T_af410_level0_col2" class="col_heading level0 col2" >spearman</th>
#       <th id="T_af410_level0_col3" class="col_heading level0 col3" >r2_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af410_level0_row0" class="row_heading level0 row0" >et_An_random_250_pgnn_</th>
#       <td id="T_af410_row0_col0" class="data row0 col0" >8.912484</td>
#       <td id="T_af410_row0_col1" class="data row0 col1" >19.565746</td>
#       <td id="T_af410_row0_col2" class="data row0 col2" >0.855289</td>
#       <td id="T_af410_row0_col3" class="data row0 col3" >0.514493</td>
#     </tr>
#     <tr>
#       <th id="T_af410_level0_row1" class="row_heading level0 row1" >et_An_random_250_mmf_</th>
#       <td id="T_af410_row1_col0" class="data row1 col0" >8.082588</td>
#       <td id="T_af410_row1_col1" class="data row1 col1" >18.117841</td>
#       <td id="T_af410_row1_col2" class="data row1 col2" >0.859724</td>
#       <td id="T_af410_row1_col3" class="data row1 col3" >0.583691</td>
#     </tr>
#     <tr>
#       <th id="T_af410_level0_row2" class="row_heading level0 row2" >et_An_random_250_mmf_pgnn_</th>
#       <td id="T_af410_row2_col0" class="data row2 col0" >8.421179</td>
#       <td id="T_af410_row2_col1" class="data row2 col1" >18.395604</td>
#       <td id="T_af410_row2_col2" class="data row2 col2" >0.861294</td>
#       <td id="T_af410_row2_col3" class="data row2 col3" >0.570829</td>
#     </tr>
#     <tr>
#       <th id="T_af410_level0_row3" class="row_heading level0 row3" >et_dflt_random_250_pgnn_</th>
#       <td id="T_af410_row3_col0" class="data row3 col0" >8.775236</td>
#       <td id="T_af410_row3_col1" class="data row3 col1" >19.223841</td>
#       <td id="T_af410_row3_col2" class="data row3 col2" >0.863953</td>
#       <td id="T_af410_row3_col3" class="data row3 col3" >0.531313</td>
#     </tr>
#     <tr>
#       <th id="T_af410_level0_row4" class="row_heading level0 row4" >et_dflt_random_250_mmf_</th>
#       <td id="T_af410_row4_col0" class="data row4 col0" >7.545741</td>
#       <td id="T_af410_row4_col1" class="data row4 col1" >18.001918</td>
#       <td id="T_af410_row4_col2" class="data row4 col2" >0.888101</td>
#       <td id="T_af410_row4_col3" class="data row4 col3" >0.589002</td>
#     </tr>
#     <tr>
#       <th id="T_af410_level0_row5" class="row_heading level0 row5" >et_dflt_random_250_mmf_pgnn_</th>
#       <td id="T_af410_row5_col0" class="data row5 col0" >8.358040</td>
#       <td id="T_af410_row5_col1" class="data row5 col1" >18.637842</td>
#       <td id="T_af410_row5_col2" class="data row5 col2" >0.881947</td>
#       <td id="T_af410_row5_col3" class="data row5 col3" >0.559451</td>
#     </tr>
#     <tr>
#       <th id="T_af410_level0_row6" class="row_heading level0 row6" >mean_value_random_250_</th>
#       <td id="T_af410_row6_col0" class="data row6 col0" >16.953476</td>
#       <td id="T_af410_row6_col1" class="data row6 col1" >28.115598</td>
#       <td id="T_af410_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_af410_row6_col3" class="data row6 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_af410_level0_row7" class="row_heading level0 row7" >modnet_random_250_pgnn_</th>
#       <td id="T_af410_row7_col0" class="data row7 col0" >7.761428</td>
#       <td id="T_af410_row7_col1" class="data row7 col1" >18.943342</td>
#       <td id="T_af410_row7_col2" class="data row7 col2" >0.891700</td>
#       <td id="T_af410_row7_col3" class="data row7 col3" >0.544891</td>
#     </tr>
#     <tr>
#       <th id="T_af410_level0_row8" class="row_heading level0 row8" >modnet_random_250_mmf_</th>
#       <td id="T_af410_row8_col0" class="data row8 col0" >8.180140</td>
#       <td id="T_af410_row8_col1" class="data row8 col1" >19.811614</td>
#       <td id="T_af410_row8_col2" class="data row8 col2" >0.905217</td>
#       <td id="T_af410_row8_col3" class="data row8 col3" >0.502214</td>
#     </tr>
#     <tr>
#       <th id="T_af410_level0_row9" class="row_heading level0 row9" >modnet_random_250_mmf_pgnn_</th>
#       <td id="T_af410_row9_col0" class="data row9 col0" >7.669056</td>
#       <td id="T_af410_row9_col1" class="data row9 col1" >19.340598</td>
#       <td id="T_af410_row9_col2" class="data row9 col2" >0.911464</td>
#       <td id="T_af410_row9_col3" class="data row9 col3" >0.525602</td>
#     </tr>
#   </tbody>
# </table>
# distribution_125
# <style type="text/css">
# #T_a31e8_row7_col0, #T_a31e8_row7_col1, #T_a31e8_row7_col2, #T_a31e8_row7_col3 {
#   color: red;
# }
# #T_a31e8_row8_col0, #T_a31e8_row8_col1, #T_a31e8_row8_col2, #T_a31e8_row8_col3 {
#   color: red;
#   color: red;
#   color: red;
#   font-weight: bold;
# }
# </style>
# <table id="T_a31e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a31e8_level0_col0" class="col_heading level0 col0" >mae</th>
#       <th id="T_a31e8_level0_col1" class="col_heading level0 col1" >rmse</th>
#       <th id="T_a31e8_level0_col2" class="col_heading level0 col2" >spearman</th>
#       <th id="T_a31e8_level0_col3" class="col_heading level0 col3" >r2_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a31e8_level0_row0" class="row_heading level0 row0" >et_An_distribution_125_pgnn_</th>
#       <td id="T_a31e8_row0_col0" class="data row0 col0" >7.918795</td>
#       <td id="T_a31e8_row0_col1" class="data row0 col1" >16.335552</td>
#       <td id="T_a31e8_row0_col2" class="data row0 col2" >0.791066</td>
#       <td id="T_a31e8_row0_col3" class="data row0 col3" >0.647445</td>
#     </tr>
#     <tr>
#       <th id="T_a31e8_level0_row1" class="row_heading level0 row1" >et_An_distribution_125_mmf_</th>
#       <td id="T_a31e8_row1_col0" class="data row1 col0" >8.313777</td>
#       <td id="T_a31e8_row1_col1" class="data row1 col1" >16.655241</td>
#       <td id="T_a31e8_row1_col2" class="data row1 col2" >0.767476</td>
#       <td id="T_a31e8_row1_col3" class="data row1 col3" >0.633511</td>
#     </tr>
#     <tr>
#       <th id="T_a31e8_level0_row2" class="row_heading level0 row2" >et_An_distribution_125_mmf_pgnn_</th>
#       <td id="T_a31e8_row2_col0" class="data row2 col0" >7.535542</td>
#       <td id="T_a31e8_row2_col1" class="data row2 col1" >15.169931</td>
#       <td id="T_a31e8_row2_col2" class="data row2 col2" >0.793524</td>
#       <td id="T_a31e8_row2_col3" class="data row2 col3" >0.695963</td>
#     </tr>
#     <tr>
#       <th id="T_a31e8_level0_row3" class="row_heading level0 row3" >et_dflt_distribution_125_pgnn_</th>
#       <td id="T_a31e8_row3_col0" class="data row3 col0" >7.493740</td>
#       <td id="T_a31e8_row3_col1" class="data row3 col1" >15.093935</td>
#       <td id="T_a31e8_row3_col2" class="data row3 col2" >0.798667</td>
#       <td id="T_a31e8_row3_col3" class="data row3 col3" >0.699001</td>
#     </tr>
#     <tr>
#       <th id="T_a31e8_level0_row4" class="row_heading level0 row4" >et_dflt_distribution_125_mmf_</th>
#       <td id="T_a31e8_row4_col0" class="data row4 col0" >6.839354</td>
#       <td id="T_a31e8_row4_col1" class="data row4 col1" >14.120979</td>
#       <td id="T_a31e8_row4_col2" class="data row4 col2" >0.813573</td>
#       <td id="T_a31e8_row4_col3" class="data row4 col3" >0.736556</td>
#     </tr>
#     <tr>
#       <th id="T_a31e8_level0_row5" class="row_heading level0 row5" >et_dflt_distribution_125_mmf_pgnn_</th>
#       <td id="T_a31e8_row5_col0" class="data row5 col0" >7.202488</td>
#       <td id="T_a31e8_row5_col1" class="data row5 col1" >14.867961</td>
#       <td id="T_a31e8_row5_col2" class="data row5 col2" >0.815736</td>
#       <td id="T_a31e8_row5_col3" class="data row5 col3" >0.707947</td>
#     </tr>
#     <tr>
#       <th id="T_a31e8_level0_row6" class="row_heading level0 row6" >modnet_distribution_125_pgnn_</th>
#       <td id="T_a31e8_row6_col0" class="data row6 col0" >6.542703</td>
#       <td id="T_a31e8_row6_col1" class="data row6 col1" >14.962140</td>
#       <td id="T_a31e8_row6_col2" class="data row6 col2" >0.855152</td>
#       <td id="T_a31e8_row6_col3" class="data row6 col3" >0.704235</td>
#     </tr>
#     <tr>
#       <th id="T_a31e8_level0_row7" class="row_heading level0 row7" >modnet_distribution_125_mmf_</th>
#       <td id="T_a31e8_row7_col0" class="data row7 col0" >6.492044</td>
#       <td id="T_a31e8_row7_col1" class="data row7 col1" >13.945333</td>
#       <td id="T_a31e8_row7_col2" class="data row7 col2" >0.864332</td>
#       <td id="T_a31e8_row7_col3" class="data row7 col3" >0.743069</td>
#     </tr>
#     <tr>
#       <th id="T_a31e8_level0_row8" class="row_heading level0 row8" >modnet_distribution_125_mmf_pgnn_</th>
#       <td id="T_a31e8_row8_col0" class="data row8 col0" >5.567543</td>
#       <td id="T_a31e8_row8_col1" class="data row8 col1" >12.074188</td>
#       <td id="T_a31e8_row8_col2" class="data row8 col2" >0.860172</td>
#       <td id="T_a31e8_row8_col3" class="data row8 col3" >0.807392</td>
#     </tr>
#   </tbody>
# </table>
# distribution_250
# <style type="text/css">
# #T_7c793_row6_col0, #T_7c793_row6_col1, #T_7c793_row6_col2, #T_7c793_row6_col3 {
#   color: red;
#   color: red;
#   font-weight: bold;
# }
# #T_7c793_row7_col0, #T_7c793_row7_col1, #T_7c793_row7_col2, #T_7c793_row7_col3, #T_7c793_row8_col0, #T_7c793_row8_col1, #T_7c793_row8_col2, #T_7c793_row8_col3 {
#   color: red;
# }
# </style>
# <table id="T_7c793">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c793_level0_col0" class="col_heading level0 col0" >mae</th>
#       <th id="T_7c793_level0_col1" class="col_heading level0 col1" >rmse</th>
#       <th id="T_7c793_level0_col2" class="col_heading level0 col2" >spearman</th>
#       <th id="T_7c793_level0_col3" class="col_heading level0 col3" >r2_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c793_level0_row0" class="row_heading level0 row0" >et_An_distribution_250_pgnn_</th>
#       <td id="T_7c793_row0_col0" class="data row0 col0" >6.823786</td>
#       <td id="T_7c793_row0_col1" class="data row0 col1" >15.388477</td>
#       <td id="T_7c793_row0_col2" class="data row0 col2" >0.831295</td>
#       <td id="T_7c793_row0_col3" class="data row0 col3" >0.630368</td>
#     </tr>
#     <tr>
#       <th id="T_7c793_level0_row1" class="row_heading level0 row1" >et_An_distribution_250_mmf_</th>
#       <td id="T_7c793_row1_col0" class="data row1 col0" >6.949693</td>
#       <td id="T_7c793_row1_col1" class="data row1 col1" >15.245760</td>
#       <td id="T_7c793_row1_col2" class="data row1 col2" >0.798448</td>
#       <td id="T_7c793_row1_col3" class="data row1 col3" >0.637193</td>
#     </tr>
#     <tr>
#       <th id="T_7c793_level0_row2" class="row_heading level0 row2" >et_An_distribution_250_mmf_pgnn_</th>
#       <td id="T_7c793_row2_col0" class="data row2 col0" >6.630075</td>
#       <td id="T_7c793_row2_col1" class="data row2 col1" >15.324600</td>
#       <td id="T_7c793_row2_col2" class="data row2 col2" >0.834100</td>
#       <td id="T_7c793_row2_col3" class="data row2 col3" >0.633431</td>
#     </tr>
#     <tr>
#       <th id="T_7c793_level0_row3" class="row_heading level0 row3" >et_dflt_distribution_250_pgnn_</th>
#       <td id="T_7c793_row3_col0" class="data row3 col0" >6.675432</td>
#       <td id="T_7c793_row3_col1" class="data row3 col1" >15.839602</td>
#       <td id="T_7c793_row3_col2" class="data row3 col2" >0.849602</td>
#       <td id="T_7c793_row3_col3" class="data row3 col3" >0.608379</td>
#     </tr>
#     <tr>
#       <th id="T_7c793_level0_row4" class="row_heading level0 row4" >et_dflt_distribution_250_mmf_</th>
#       <td id="T_7c793_row4_col0" class="data row4 col0" >6.144405</td>
#       <td id="T_7c793_row4_col1" class="data row4 col1" >15.278746</td>
#       <td id="T_7c793_row4_col2" class="data row4 col2" >0.837960</td>
#       <td id="T_7c793_row4_col3" class="data row4 col3" >0.635621</td>
#     </tr>
#     <tr>
#       <th id="T_7c793_level0_row5" class="row_heading level0 row5" >et_dflt_distribution_250_mmf_pgnn_</th>
#       <td id="T_7c793_row5_col0" class="data row5 col0" >6.189507</td>
#       <td id="T_7c793_row5_col1" class="data row5 col1" >15.023034</td>
#       <td id="T_7c793_row5_col2" class="data row5 col2" >0.844422</td>
#       <td id="T_7c793_row5_col3" class="data row5 col3" >0.647716</td>
#     </tr>
#     <tr>
#       <th id="T_7c793_level0_row6" class="row_heading level0 row6" >modnet_distribution_250_pgnn_</th>
#       <td id="T_7c793_row6_col0" class="data row6 col0" >5.817681</td>
#       <td id="T_7c793_row6_col1" class="data row6 col1" >14.483580</td>
#       <td id="T_7c793_row6_col2" class="data row6 col2" >0.869175</td>
#       <td id="T_7c793_row6_col3" class="data row6 col3" >0.672562</td>
#     </tr>
#     <tr>
#       <th id="T_7c793_level0_row7" class="row_heading level0 row7" >modnet_distribution_250_mmf_</th>
#       <td id="T_7c793_row7_col0" class="data row7 col0" >5.609491</td>
#       <td id="T_7c793_row7_col1" class="data row7 col1" >14.656513</td>
#       <td id="T_7c793_row7_col2" class="data row7 col2" >0.869088</td>
#       <td id="T_7c793_row7_col3" class="data row7 col3" >0.664696</td>
#     </tr>
#     <tr>
#       <th id="T_7c793_level0_row8" class="row_heading level0 row8" >modnet_distribution_250_mmf_pgnn_</th>
#       <td id="T_7c793_row8_col0" class="data row8 col0" >5.765881</td>
#       <td id="T_7c793_row8_col1" class="data row8 col1" >15.279833</td>
#       <td id="T_7c793_row8_col2" class="data row8 col2" >0.883553</td>
#       <td id="T_7c793_row8_col3" class="data row8 col3" >0.635569</td>
#     </tr>
#   </tbody>
# </table>
