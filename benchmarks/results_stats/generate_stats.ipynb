# %%
from collections import Counter
from pathlib import Path

import json
import os
import pandas as pd

# %%
# 1. Lists all directories in the previous dir
# 2. Create a dict with the name of the models as keys
# 3. The values will be a new dict with the denomination of the "tasks_..." or "tasks" dir as key
# 4. The values of this last dict will be a new dict with the task (or split) as key so random_125 for example
# 5. The values of this last dict will be a new dict with the type of features (mmf e.g.) as key
# 6. The values of this last dict will be a new dict with the name of the metric as key
# 7. The values of this last dict will be the metric itself

# %%
# 1. Lists all directories in the previous dir
path_benchmarks = Path("..")
model_names = next(os.walk(path_benchmarks), (None, None, []))[1]
model_names.remove("results_stats")
model_names
# Out:
# ['modnet_nan', 'matten', 'modnet', 'mean_value', 'et', 'lgbm']

# %%
# 2. Create a dict with the name of the models as keys
dict_results = {m: {} for m in model_names}
dict_results
# Out:
# {'modnet_nan': {},
#  'matten': {},
#  'modnet': {},
#  'mean_value': {},
#  'et': {},
#  'lgbm': {}}

# %%
# 3. The values will be a new dict with the denomination of the "tasks_..." or "tasks" dir as key
for m in dict_results.keys():
    path_tasks = path_benchmarks / m
    for d in next(os.walk(path_tasks), (None, None, []))[1]:
        if "tasks" in d:
            dict_results[m].update({d: {}})

print(dict_results)
# Out:
# {'modnet_nan': {'tasks': {}}, 'matten': {}, 'modnet': {'tasks': {}}, 'mean_value': {'tasks': {}}, 'et': {'tasks_dflt': {}, 'tasks_An': {}}, 'lgbm': {'tasks_dflt': {}, 'tasks_An': {}}}

# %%
# 4. The values of this last dict will be a new dict with the task (or split) as key so random_125 for example
for m in dict_results.keys():
    path_tasks = path_benchmarks / m
    for t in dict_results[m].keys():
        path_split = path_tasks / t
        for d in next(os.walk(path_split), (None, None, []))[1]:
            if "distribution" in d or "random" in d:
                dict_results[m][t].update({d: {}})

print(dict_results)
# Out:
# {'modnet_nan': {'tasks': {'distribution_125': {}, 'distribution_250': {}, 'random_125': {}, 'random_250': {}}}, 'matten': {}, 'modnet': {'tasks': {'distribution_125': {}, 'distribution_250': {}, 'random_125': {}, 'random_250': {}}}, 'mean_value': {'tasks': {'random_250': {}}}, 'et': {'tasks_dflt': {'distribution_125': {}, 'distribution_250': {}, 'random_125': {}, 'random_250': {}}, 'tasks_An': {'distribution_125': {}, 'distribution_250': {}, 'random_125': {}, 'random_250': {}}}, 'lgbm': {'tasks_dflt': {'distribution_125': {}, 'distribution_250': {}, 'random_125': {}, 'random_250': {}}, 'tasks_An': {'distribution_125': {}, 'distribution_250': {}, 'random_125': {}, 'random_250': {}}}}

# %%
# 5. The values of this last dict will be a new dict with the type of features (mmf e.g.) as key
for m in dict_results.keys():
    path_tasks = path_benchmarks / m
    for t in dict_results[m].keys():
        path_split = path_tasks / t
        for s in dict_results[m][t].keys():
            path_feat = path_split / s

            for f in next(os.walk(path_feat), (None, None, []))[2]:
                if "json" not in f:
                    continue
                path_results = path_feat / f
                with open(path_results, 'r') as file:
                    results = json.load(file)
                dict_results[m][t][s].update({f.split(".json")[0]: results['metrics']})

# display(dict_results)

# %%
f = {}
stack = [(dict_results, '')]  # Stack holds tuples of (current_dict, current_key)

while stack:
    c, p = stack.pop()
    
    for k, v in c.items():
        new_key = f"{p}_{k}" if p else k
        
        if isinstance(v, dict):
            stack.append((v, new_key))  # Push the nested dictionary onto the stack
        else:
            f[new_key] = v  # Add to the flattened dictionary

# print(f)

# %%
dict_results_ravel = {}
for k, v in f.items():
    new_k, metric = k.replace("_tasks","").split("results_")
    if new_k not in dict_results_ravel.keys():
        dict_results_ravel[new_k] = {}
    dict_results_ravel[new_k][metric] = v

# %%
def df_style(val):
    return "color: red"
def df_style_bold(val):
    return "font-weight: bold"
import numpy as np
def highlight_max(s, props='color:red'):
    return np.where(s == np.nanmax(s.values), props, '')

df_results = pd.DataFrame.from_dict(dict_results_ravel, orient="index")

dict_df_results_splits = {}
for split in ["random_125", "random_250", "distribution_125", "distribution_250"]:
    indexes = []
    for i in df_results.index:
        if split in i:
            indexes.append(i)
    df_tmp = df_results.filter(indexes, axis=0)
    new_index = []
    for i in df_tmp.index:
        new_index.append(i.replace(split,"").replace("__","_"))
    df_tmp.index = new_index
    df_tmp = df_tmp.sort_values(by="spearman", ascending=False)


    # and apply styling to it via the `subset` arg; first arg is styler function above
    idx_best = []
    idx_best.extend(df_tmp[['mae', 'rmse']].idxmin().tolist())
    idx_best.extend(df_tmp[['spearman', 'r2_score']].idxmax().tolist())
    df_tmp = df_tmp.style.applymap(df_style, subset=(idx_best, ["mae", "rmse", "spearman", "r2_score"]))

    idx_best_max, idx_best_max_count = Counter(idx_best).most_common(1)[0]
    if idx_best_max_count > 1:
        df_tmp = df_tmp.applymap(df_style_bold, subset=([idx_best_max], ["mae", "rmse", "spearman", "r2_score"]))

    dict_df_results_splits[split] = df_tmp

    print(split)
    display(dict_df_results_splits[split])
# Out:
# random_125
# <style type="text/css">
# #T_9357b_row0_col0, #T_9357b_row0_col1, #T_9357b_row0_col2, #T_9357b_row0_col3, #T_9357b_row2_col0, #T_9357b_row2_col1, #T_9357b_row2_col2, #T_9357b_row2_col3 {
#   color: red;
# }
# #T_9357b_row11_col0, #T_9357b_row11_col1, #T_9357b_row11_col2, #T_9357b_row11_col3 {
#   color: red;
#   color: red;
#   font-weight: bold;
# }
# </style>
# <table id="T_9357b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9357b_level0_col0" class="col_heading level0 col0" >mae</th>
#       <th id="T_9357b_level0_col1" class="col_heading level0 col1" >rmse</th>
#       <th id="T_9357b_level0_col2" class="col_heading level0 col2" >spearman</th>
#       <th id="T_9357b_level0_col3" class="col_heading level0 col3" >r2_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9357b_level0_row0" class="row_heading level0 row0" >modnet_mmf_pgnn_</th>
#       <td id="T_9357b_row0_col0" class="data row0 col0" >7.304253</td>
#       <td id="T_9357b_row0_col1" class="data row0 col1" >19.423989</td>
#       <td id="T_9357b_row0_col2" class="data row0 col2" >0.916129</td>
#       <td id="T_9357b_row0_col3" class="data row0 col3" >0.600429</td>
#     </tr>
#     <tr>
#       <th id="T_9357b_level0_row1" class="row_heading level0 row1" >modnet_nan_mmf_</th>
#       <td id="T_9357b_row1_col0" class="data row1 col0" >8.575768</td>
#       <td id="T_9357b_row1_col1" class="data row1 col1" >22.312438</td>
#       <td id="T_9357b_row1_col2" class="data row1 col2" >0.914353</td>
#       <td id="T_9357b_row1_col3" class="data row1 col3" >0.472757</td>
#     </tr>
#     <tr>
#       <th id="T_9357b_level0_row2" class="row_heading level0 row2" >modnet_nan_mmf_pgnn_</th>
#       <td id="T_9357b_row2_col0" class="data row2 col0" >7.207251</td>
#       <td id="T_9357b_row2_col1" class="data row2 col1" >19.035574</td>
#       <td id="T_9357b_row2_col2" class="data row2 col2" >0.914292</td>
#       <td id="T_9357b_row2_col3" class="data row2 col3" >0.616250</td>
#     </tr>
#     <tr>
#       <th id="T_9357b_level0_row3" class="row_heading level0 row3" >modnet_mmf_</th>
#       <td id="T_9357b_row3_col0" class="data row3 col0" >8.803178</td>
#       <td id="T_9357b_row3_col1" class="data row3 col1" >23.035541</td>
#       <td id="T_9357b_row3_col2" class="data row3 col2" >0.907785</td>
#       <td id="T_9357b_row3_col3" class="data row3 col3" >0.438029</td>
#     </tr>
#     <tr>
#       <th id="T_9357b_level0_row4" class="row_heading level0 row4" >modnet_pgnn_</th>
#       <td id="T_9357b_row4_col0" class="data row4 col0" >8.262533</td>
#       <td id="T_9357b_row4_col1" class="data row4 col1" >19.751812</td>
#       <td id="T_9357b_row4_col2" class="data row4 col2" >0.901475</td>
#       <td id="T_9357b_row4_col3" class="data row4 col3" >0.586828</td>
#     </tr>
#     <tr>
#       <th id="T_9357b_level0_row5" class="row_heading level0 row5" >modnet_nan_pgnn_</th>
#       <td id="T_9357b_row5_col0" class="data row5 col0" >8.112097</td>
#       <td id="T_9357b_row5_col1" class="data row5 col1" >19.017002</td>
#       <td id="T_9357b_row5_col2" class="data row5 col2" >0.900725</td>
#       <td id="T_9357b_row5_col3" class="data row5 col3" >0.616998</td>
#     </tr>
#     <tr>
#       <th id="T_9357b_level0_row6" class="row_heading level0 row6" >et_dflt_mmf_pgnn_</th>
#       <td id="T_9357b_row6_col0" class="data row6 col0" >8.307911</td>
#       <td id="T_9357b_row6_col1" class="data row6 col1" >19.589507</td>
#       <td id="T_9357b_row6_col2" class="data row6 col2" >0.894224</td>
#       <td id="T_9357b_row6_col3" class="data row6 col3" >0.593591</td>
#     </tr>
#     <tr>
#       <th id="T_9357b_level0_row7" class="row_heading level0 row7" >et_dflt_mmf_</th>
#       <td id="T_9357b_row7_col0" class="data row7 col0" >8.192585</td>
#       <td id="T_9357b_row7_col1" class="data row7 col1" >19.784299</td>
#       <td id="T_9357b_row7_col2" class="data row7 col2" >0.892774</td>
#       <td id="T_9357b_row7_col3" class="data row7 col3" >0.585468</td>
#     </tr>
#     <tr>
#       <th id="T_9357b_level0_row8" class="row_heading level0 row8" >et_dflt_pgnn_</th>
#       <td id="T_9357b_row8_col0" class="data row8 col0" >8.341509</td>
#       <td id="T_9357b_row8_col1" class="data row8 col1" >19.831881</td>
#       <td id="T_9357b_row8_col2" class="data row8 col2" >0.889002</td>
#       <td id="T_9357b_row8_col3" class="data row8 col3" >0.583472</td>
#     </tr>
#     <tr>
#       <th id="T_9357b_level0_row9" class="row_heading level0 row9" >et_An_pgnn_</th>
#       <td id="T_9357b_row9_col0" class="data row9 col0" >8.647093</td>
#       <td id="T_9357b_row9_col1" class="data row9 col1" >20.012587</td>
#       <td id="T_9357b_row9_col2" class="data row9 col2" >0.886495</td>
#       <td id="T_9357b_row9_col3" class="data row9 col3" >0.575846</td>
#     </tr>
#     <tr>
#       <th id="T_9357b_level0_row10" class="row_heading level0 row10" >et_An_mmf_</th>
#       <td id="T_9357b_row10_col0" class="data row10 col0" >8.647552</td>
#       <td id="T_9357b_row10_col1" class="data row10 col1" >19.931938</td>
#       <td id="T_9357b_row10_col2" class="data row10 col2" >0.882402</td>
#       <td id="T_9357b_row10_col3" class="data row10 col3" >0.579258</td>
#     </tr>
#     <tr>
#       <th id="T_9357b_level0_row11" class="row_heading level0 row11" >lgbm_dflt_mmf_pgnn_</th>
#       <td id="T_9357b_row11_col0" class="data row11 col0" >7.689738</td>
#       <td id="T_9357b_row11_col1" class="data row11 col1" >18.333103</td>
#       <td id="T_9357b_row11_col2" class="data row11 col2" >0.880614</td>
#       <td id="T_9357b_row11_col3" class="data row11 col3" >0.644050</td>
#     </tr>
#     <tr>
#       <th id="T_9357b_level0_row12" class="row_heading level0 row12" >lgbm_dflt_mmf_</th>
#       <td id="T_9357b_row12_col0" class="data row12 col0" >7.743431</td>
#       <td id="T_9357b_row12_col1" class="data row12 col1" >18.366044</td>
#       <td id="T_9357b_row12_col2" class="data row12 col2" >0.879220</td>
#       <td id="T_9357b_row12_col3" class="data row12 col3" >0.642770</td>
#     </tr>
#     <tr>
#       <th id="T_9357b_level0_row13" class="row_heading level0 row13" >et_An_mmf_pgnn_</th>
#       <td id="T_9357b_row13_col0" class="data row13 col0" >8.537435</td>
#       <td id="T_9357b_row13_col1" class="data row13 col1" >19.984474</td>
#       <td id="T_9357b_row13_col2" class="data row13 col2" >0.877677</td>
#       <td id="T_9357b_row13_col3" class="data row13 col3" >0.577037</td>
#     </tr>
#     <tr>
#       <th id="T_9357b_level0_row14" class="row_heading level0 row14" >lgbm_dflt_pgnn_</th>
#       <td id="T_9357b_row14_col0" class="data row14 col0" >8.861628</td>
#       <td id="T_9357b_row14_col1" class="data row14 col1" >21.021451</td>
#       <td id="T_9357b_row14_col2" class="data row14 col2" >0.875619</td>
#       <td id="T_9357b_row14_col3" class="data row14 col3" >0.532004</td>
#     </tr>
#     <tr>
#       <th id="T_9357b_level0_row15" class="row_heading level0 row15" >lgbm_An_mmf_pgnn_</th>
#       <td id="T_9357b_row15_col0" class="data row15 col0" >9.151583</td>
#       <td id="T_9357b_row15_col1" class="data row15 col1" >19.734747</td>
#       <td id="T_9357b_row15_col2" class="data row15 col2" >0.852442</td>
#       <td id="T_9357b_row15_col3" class="data row15 col3" >0.587542</td>
#     </tr>
#     <tr>
#       <th id="T_9357b_level0_row16" class="row_heading level0 row16" >lgbm_An_pgnn_</th>
#       <td id="T_9357b_row16_col0" class="data row16 col0" >10.001763</td>
#       <td id="T_9357b_row16_col1" class="data row16 col1" >22.092309</td>
#       <td id="T_9357b_row16_col2" class="data row16 col2" >0.846943</td>
#       <td id="T_9357b_row16_col3" class="data row16 col3" >0.483109</td>
#     </tr>
#     <tr>
#       <th id="T_9357b_level0_row17" class="row_heading level0 row17" >lgbm_An_mmf_</th>
#       <td id="T_9357b_row17_col0" class="data row17 col0" >8.867190</td>
#       <td id="T_9357b_row17_col1" class="data row17 col1" >20.112379</td>
#       <td id="T_9357b_row17_col2" class="data row17 col2" >0.837309</td>
#       <td id="T_9357b_row17_col3" class="data row17 col3" >0.571606</td>
#     </tr>
#   </tbody>
# </table>
# random_250
# <style type="text/css">
# #T_30fc4_row0_col0, #T_30fc4_row0_col1, #T_30fc4_row0_col2, #T_30fc4_row0_col3 {
#   color: red;
# }
# #T_30fc4_row6_col0, #T_30fc4_row6_col1, #T_30fc4_row6_col2, #T_30fc4_row6_col3 {
#   color: red;
#   color: red;
#   color: red;
#   font-weight: bold;
# }
# </style>
# <table id="T_30fc4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30fc4_level0_col0" class="col_heading level0 col0" >mae</th>
#       <th id="T_30fc4_level0_col1" class="col_heading level0 col1" >rmse</th>
#       <th id="T_30fc4_level0_col2" class="col_heading level0 col2" >spearman</th>
#       <th id="T_30fc4_level0_col3" class="col_heading level0 col3" >r2_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30fc4_level0_row0" class="row_heading level0 row0" >modnet_mmf_pgnn_</th>
#       <td id="T_30fc4_row0_col0" class="data row0 col0" >7.669056</td>
#       <td id="T_30fc4_row0_col1" class="data row0 col1" >19.340598</td>
#       <td id="T_30fc4_row0_col2" class="data row0 col2" >0.911464</td>
#       <td id="T_30fc4_row0_col3" class="data row0 col3" >0.525602</td>
#     </tr>
#     <tr>
#       <th id="T_30fc4_level0_row1" class="row_heading level0 row1" >modnet_mmf_</th>
#       <td id="T_30fc4_row1_col0" class="data row1 col0" >8.180140</td>
#       <td id="T_30fc4_row1_col1" class="data row1 col1" >19.811614</td>
#       <td id="T_30fc4_row1_col2" class="data row1 col2" >0.905217</td>
#       <td id="T_30fc4_row1_col3" class="data row1 col3" >0.502214</td>
#     </tr>
#     <tr>
#       <th id="T_30fc4_level0_row2" class="row_heading level0 row2" >modnet_nan_mmf_pgnn_</th>
#       <td id="T_30fc4_row2_col0" class="data row2 col0" >7.694188</td>
#       <td id="T_30fc4_row2_col1" class="data row2 col1" >19.223358</td>
#       <td id="T_30fc4_row2_col2" class="data row2 col2" >0.904237</td>
#       <td id="T_30fc4_row2_col3" class="data row2 col3" >0.531336</td>
#     </tr>
#     <tr>
#       <th id="T_30fc4_level0_row3" class="row_heading level0 row3" >modnet_nan_mmf_</th>
#       <td id="T_30fc4_row3_col0" class="data row3 col0" >8.079505</td>
#       <td id="T_30fc4_row3_col1" class="data row3 col1" >19.572426</td>
#       <td id="T_30fc4_row3_col2" class="data row3 col2" >0.902699</td>
#       <td id="T_30fc4_row3_col3" class="data row3 col3" >0.514161</td>
#     </tr>
#     <tr>
#       <th id="T_30fc4_level0_row4" class="row_heading level0 row4" >modnet_nan_pgnn_</th>
#       <td id="T_30fc4_row4_col0" class="data row4 col0" >7.931116</td>
#       <td id="T_30fc4_row4_col1" class="data row4 col1" >18.978913</td>
#       <td id="T_30fc4_row4_col2" class="data row4 col2" >0.891716</td>
#       <td id="T_30fc4_row4_col3" class="data row4 col3" >0.543180</td>
#     </tr>
#     <tr>
#       <th id="T_30fc4_level0_row5" class="row_heading level0 row5" >modnet_pgnn_</th>
#       <td id="T_30fc4_row5_col0" class="data row5 col0" >7.761428</td>
#       <td id="T_30fc4_row5_col1" class="data row5 col1" >18.943342</td>
#       <td id="T_30fc4_row5_col2" class="data row5 col2" >0.891700</td>
#       <td id="T_30fc4_row5_col3" class="data row5 col3" >0.544891</td>
#     </tr>
#     <tr>
#       <th id="T_30fc4_level0_row6" class="row_heading level0 row6" >et_dflt_mmf_</th>
#       <td id="T_30fc4_row6_col0" class="data row6 col0" >7.545741</td>
#       <td id="T_30fc4_row6_col1" class="data row6 col1" >18.001918</td>
#       <td id="T_30fc4_row6_col2" class="data row6 col2" >0.888101</td>
#       <td id="T_30fc4_row6_col3" class="data row6 col3" >0.589002</td>
#     </tr>
#     <tr>
#       <th id="T_30fc4_level0_row7" class="row_heading level0 row7" >et_dflt_mmf_pgnn_</th>
#       <td id="T_30fc4_row7_col0" class="data row7 col0" >8.358040</td>
#       <td id="T_30fc4_row7_col1" class="data row7 col1" >18.637842</td>
#       <td id="T_30fc4_row7_col2" class="data row7 col2" >0.881947</td>
#       <td id="T_30fc4_row7_col3" class="data row7 col3" >0.559451</td>
#     </tr>
#     <tr>
#       <th id="T_30fc4_level0_row8" class="row_heading level0 row8" >lgbm_dflt_mmf_pgnn_</th>
#       <td id="T_30fc4_row8_col0" class="data row8 col0" >9.191596</td>
#       <td id="T_30fc4_row8_col1" class="data row8 col1" >19.964367</td>
#       <td id="T_30fc4_row8_col2" class="data row8 col2" >0.865527</td>
#       <td id="T_30fc4_row8_col3" class="data row8 col3" >0.494509</td>
#     </tr>
#     <tr>
#       <th id="T_30fc4_level0_row9" class="row_heading level0 row9" >et_dflt_pgnn_</th>
#       <td id="T_30fc4_row9_col0" class="data row9 col0" >8.775236</td>
#       <td id="T_30fc4_row9_col1" class="data row9 col1" >19.223841</td>
#       <td id="T_30fc4_row9_col2" class="data row9 col2" >0.863953</td>
#       <td id="T_30fc4_row9_col3" class="data row9 col3" >0.531313</td>
#     </tr>
#     <tr>
#       <th id="T_30fc4_level0_row10" class="row_heading level0 row10" >et_An_mmf_pgnn_</th>
#       <td id="T_30fc4_row10_col0" class="data row10 col0" >8.421179</td>
#       <td id="T_30fc4_row10_col1" class="data row10 col1" >18.395604</td>
#       <td id="T_30fc4_row10_col2" class="data row10 col2" >0.861294</td>
#       <td id="T_30fc4_row10_col3" class="data row10 col3" >0.570829</td>
#     </tr>
#     <tr>
#       <th id="T_30fc4_level0_row11" class="row_heading level0 row11" >et_An_mmf_</th>
#       <td id="T_30fc4_row11_col0" class="data row11 col0" >8.082588</td>
#       <td id="T_30fc4_row11_col1" class="data row11 col1" >18.117841</td>
#       <td id="T_30fc4_row11_col2" class="data row11 col2" >0.859724</td>
#       <td id="T_30fc4_row11_col3" class="data row11 col3" >0.583691</td>
#     </tr>
#     <tr>
#       <th id="T_30fc4_level0_row12" class="row_heading level0 row12" >et_An_pgnn_</th>
#       <td id="T_30fc4_row12_col0" class="data row12 col0" >8.912484</td>
#       <td id="T_30fc4_row12_col1" class="data row12 col1" >19.565746</td>
#       <td id="T_30fc4_row12_col2" class="data row12 col2" >0.855289</td>
#       <td id="T_30fc4_row12_col3" class="data row12 col3" >0.514493</td>
#     </tr>
#     <tr>
#       <th id="T_30fc4_level0_row13" class="row_heading level0 row13" >lgbm_dflt_pgnn_</th>
#       <td id="T_30fc4_row13_col0" class="data row13 col0" >8.964196</td>
#       <td id="T_30fc4_row13_col1" class="data row13 col1" >19.642232</td>
#       <td id="T_30fc4_row13_col2" class="data row13 col2" >0.853225</td>
#       <td id="T_30fc4_row13_col3" class="data row13 col3" >0.510690</td>
#     </tr>
#     <tr>
#       <th id="T_30fc4_level0_row14" class="row_heading level0 row14" >lgbm_An_mmf_pgnn_</th>
#       <td id="T_30fc4_row14_col0" class="data row14 col0" >9.127552</td>
#       <td id="T_30fc4_row14_col1" class="data row14 col1" >19.763387</td>
#       <td id="T_30fc4_row14_col2" class="data row14 col2" >0.852039</td>
#       <td id="T_30fc4_row14_col3" class="data row14 col3" >0.504635</td>
#     </tr>
#     <tr>
#       <th id="T_30fc4_level0_row15" class="row_heading level0 row15" >lgbm_dflt_mmf_</th>
#       <td id="T_30fc4_row15_col0" class="data row15 col0" >8.071111</td>
#       <td id="T_30fc4_row15_col1" class="data row15 col1" >18.428455</td>
#       <td id="T_30fc4_row15_col2" class="data row15 col2" >0.843201</td>
#       <td id="T_30fc4_row15_col3" class="data row15 col3" >0.569294</td>
#     </tr>
#     <tr>
#       <th id="T_30fc4_level0_row16" class="row_heading level0 row16" >lgbm_An_pgnn_</th>
#       <td id="T_30fc4_row16_col0" class="data row16 col0" >9.420131</td>
#       <td id="T_30fc4_row16_col1" class="data row16 col1" >20.438576</td>
#       <td id="T_30fc4_row16_col2" class="data row16 col2" >0.842432</td>
#       <td id="T_30fc4_row16_col3" class="data row16 col3" >0.470210</td>
#     </tr>
#     <tr>
#       <th id="T_30fc4_level0_row17" class="row_heading level0 row17" >lgbm_An_mmf_</th>
#       <td id="T_30fc4_row17_col0" class="data row17 col0" >8.016118</td>
#       <td id="T_30fc4_row17_col1" class="data row17 col1" >18.092160</td>
#       <td id="T_30fc4_row17_col2" class="data row17 col2" >0.825054</td>
#       <td id="T_30fc4_row17_col3" class="data row17 col3" >0.584871</td>
#     </tr>
#     <tr>
#       <th id="T_30fc4_level0_row18" class="row_heading level0 row18" >mean_value_</th>
#       <td id="T_30fc4_row18_col0" class="data row18
# distribution_125
# <style type="text/css">
# #T_5edd6_row0_col0, #T_5edd6_row0_col1, #T_5edd6_row0_col2, #T_5edd6_row0_col3 {
#   color: red;
# }
# #T_5edd6_row3_col0, #T_5edd6_row3_col1, #T_5edd6_row3_col2, #T_5edd6_row3_col3 {
#   color: red;
#   color: red;
#   color: red;
#   font-weight: bold;
# }
# </style>
# <table id="T_5edd6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5edd6_level0_col0" class="col_heading level0 col0" >mae</th>
#       <th id="T_5edd6_level0_col1" class="col_heading level0 col1" >rmse</th>
#       <th id="T_5edd6_level0_col2" class="col_heading level0 col2" >spearman</th>
#       <th id="T_5edd6_level0_col3" class="col_heading level0 col3" >r2_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5edd6_level0_row0" class="row_heading level0 row0" >modnet_nan_mmf_pgnn_</th>
#       <td id="T_5edd6_row0_col0" class="data row0 col0" >6.050881</td>
#       <td id="T_5edd6_row0_col1" class="data row0 col1" >14.269081</td>
#       <td id="T_5edd6_row0_col2" class="data row0 col2" >0.885794</td>
#       <td id="T_5edd6_row0_col3" class="data row0 col3" >0.731001</td>
#     </tr>
#     <tr>
#       <th id="T_5edd6_level0_row1" class="row_heading level0 row1" >modnet_nan_mmf_</th>
#       <td id="T_5edd6_row1_col0" class="data row1 col0" >6.322740</td>
#       <td id="T_5edd6_row1_col1" class="data row1 col1" >13.445159</td>
#       <td id="T_5edd6_row1_col2" class="data row1 col2" >0.865438</td>
#       <td id="T_5edd6_row1_col3" class="data row1 col3" >0.761169</td>
#     </tr>
#     <tr>
#       <th id="T_5edd6_level0_row2" class="row_heading level0 row2" >modnet_mmf_</th>
#       <td id="T_5edd6_row2_col0" class="data row2 col0" >6.492044</td>
#       <td id="T_5edd6_row2_col1" class="data row2 col1" >13.945333</td>
#       <td id="T_5edd6_row2_col2" class="data row2 col2" >0.864332</td>
#       <td id="T_5edd6_row2_col3" class="data row2 col3" >0.743069</td>
#     </tr>
#     <tr>
#       <th id="T_5edd6_level0_row3" class="row_heading level0 row3" >modnet_mmf_pgnn_</th>
#       <td id="T_5edd6_row3_col0" class="data row3 col0" >5.567543</td>
#       <td id="T_5edd6_row3_col1" class="data row3 col1" >12.074188</td>
#       <td id="T_5edd6_row3_col2" class="data row3 col2" >0.860172</td>
#       <td id="T_5edd6_row3_col3" class="data row3 col3" >0.807392</td>
#     </tr>
#     <tr>
#       <th id="T_5edd6_level0_row4" class="row_heading level0 row4" >modnet_pgnn_</th>
#       <td id="T_5edd6_row4_col0" class="data row4 col0" >6.542703</td>
#       <td id="T_5edd6_row4_col1" class="data row4 col1" >14.962140</td>
#       <td id="T_5edd6_row4_col2" class="data row4 col2" >0.855152</td>
#       <td id="T_5edd6_row4_col3" class="data row4 col3" >0.704235</td>
#     </tr>
#     <tr>
#       <th id="T_5edd6_level0_row5" class="row_heading level0 row5" >modnet_nan_pgnn_</th>
#       <td id="T_5edd6_row5_col0" class="data row5 col0" >6.560970</td>
#       <td id="T_5edd6_row5_col1" class="data row5 col1" >14.911195</td>
#       <td id="T_5edd6_row5_col2" class="data row5 col2" >0.844104</td>
#       <td id="T_5edd6_row5_col3" class="data row5 col3" >0.706246</td>
#     </tr>
#     <tr>
#       <th id="T_5edd6_level0_row6" class="row_heading level0 row6" >lgbm_dflt_mmf_pgnn_</th>
#       <td id="T_5edd6_row6_col0" class="data row6 col0" >7.301577</td>
#       <td id="T_5edd6_row6_col1" class="data row6 col1" >14.945985</td>
#       <td id="T_5edd6_row6_col2" class="data row6 col2" >0.843207</td>
#       <td id="T_5edd6_row6_col3" class="data row6 col3" >0.704873</td>
#     </tr>
#     <tr>
#       <th id="T_5edd6_level0_row7" class="row_heading level0 row7" >et_dflt_mmf_pgnn_</th>
#       <td id="T_5edd6_row7_col0" class="data row7 col0" >7.202488</td>
#       <td id="T_5edd6_row7_col1" class="data row7 col1" >14.867961</td>
#       <td id="T_5edd6_row7_col2" class="data row7 col2" >0.815736</td>
#       <td id="T_5edd6_row7_col3" class="data row7 col3" >0.707947</td>
#     </tr>
#     <tr>
#       <th id="T_5edd6_level0_row8" class="row_heading level0 row8" >et_dflt_mmf_</th>
#       <td id="T_5edd6_row8_col0" class="data row8 col0" >6.839354</td>
#       <td id="T_5edd6_row8_col1" class="data row8 col1" >14.120979</td>
#       <td id="T_5edd6_row8_col2" class="data row8 col2" >0.813573</td>
#       <td id="T_5edd6_row8_col3" class="data row8 col3" >0.736556</td>
#     </tr>
#     <tr>
#       <th id="T_5edd6_level0_row9" class="row_heading level0 row9" >lgbm_An_mmf_pgnn_</th>
#       <td id="T_5edd6_row9_col0" class="data row9 col0" >7.884289</td>
#       <td id="T_5edd6_row9_col1" class="data row9 col1" >17.348162</td>
#       <td id="T_5edd6_row9_col2" class="data row9 col2" >0.810488</td>
#       <td id="T_5edd6_row9_col3" class="data row9 col3" >0.602382</td>
#     </tr>
#     <tr>
#       <th id="T_5edd6_level0_row10" class="row_heading level0 row10" >lgbm_dflt_mmf_</th>
#       <td id="T_5edd6_row10_col0" class="data row10 col0" >6.904597</td>
#       <td id="T_5edd6_row10_col1" class="data row10 col1" >13.838455</td>
#       <td id="T_5edd6_row10_col2" class="data row10 col2" >0.806748</td>
#       <td id="T_5edd6_row10_col3" class="data row10 col3" >0.746992</td>
#     </tr>
#     <tr>
#       <th id="T_5edd6_level0_row11" class="row_heading level0 row11" >lgbm_An_mmf_</th>
#       <td id="T_5edd6_row11_col0" class="data row11 col0" >7.494076</td>
#       <td id="T_5edd6_row11_col1" class="data row11 col1" >14.547788</td>
#       <td id="T_5edd6_row11_col2" class="data row11 col2" >0.806273</td>
#       <td id="T_5edd6_row11_col3" class="data row11 col3" >0.720390</td>
#     </tr>
#     <tr>
#       <th id="T_5edd6_level0_row12" class="row_heading level0 row12" >et_dflt_pgnn_</th>
#       <td id="T_5edd6_row12_col0" class="data row12 col0" >7.493740</td>
#       <td id="T_5edd6_row12_col1" class="data row12 col1" >15.093935</td>
#       <td id="T_5edd6_row12_col2" class="data row12 col2" >0.798667</td>
#       <td id="T_5edd6_row12_col3" class="data row12 col3" >0.699001</td>
#     </tr>
#     <tr>
#       <th id="T_5edd6_level0_row13" class="row_heading level0 row13" >lgbm_dflt_pgnn_</th>
#       <td id="T_5edd6_row13_col0" class="data row13 col0" >8.085883</td>
#       <td id="T_5edd6_row13_col1" class="data row13 col1" >16.197706</td>
#       <td id="T_5edd6_row13_col2" class="data row13 col2" >0.798568</td>
#       <td id="T_5edd6_row13_col3" class="data row13 col3" >0.653370</td>
#     </tr>
#     <tr>
#       <th id="T_5edd6_level0_row14" class="row_heading level0 row14" >et_An_mmf_pgnn_</th>
#       <td id="T_5edd6_row14_col0" class="data row14 col0" >7.535542</td>
#       <td id="T_5edd6_row14_col1" class="data row14 col1" >15.169931</td>
#       <td id="T_5edd6_row14_col2" class="data row14 col2" >0.793524</td>
#       <td id="T_5edd6_row14_col3" class="data row14 col3" >0.695963</td>
#     </tr>
#     <tr>
#       <th id="T_5edd6_level0_row15" class="row_heading level0 row15" >et_An_pgnn_</th>
#       <td id="T_5edd6_row15_col0" class="data row15 col0" >7.918795</td>
#       <td id="T_5edd6_row15_col1" class="data row15 col1" >16.335552</td>
#       <td id="T_5edd6_row15_col2" class="data row15 col2" >0.791066</td>
#       <td id="T_5edd6_row15_col3" class="data row15 col3" >0.647445</td>
#     </tr>
#     <tr>
#       <th id="T_5edd6_level0_row16" class="row_heading level0 row16" >lgbm_An_pgnn_</th>
#       <td id="T_5edd6_row16_col0" class="data row16 col0" >8.297967</td>
#       <td id="T_5edd6_row16_col1" class="data row16 col1" >17.074869</td>
#       <td id="T_5edd6_row16_col2" class="data row16 col2" >0.781874</td>
#       <td id="T_5edd6_row16_col3" class="data row16 col3" >0.614811</td>
#     </tr>
#     <tr>
#       <th id="T_5edd6_level0_row17" class="row_heading level0 row17" >et_An_mmf_</th>
#       <td id="T_5edd6_row17_col0" class="data row17 col0" >8.313777</td>
#       <td id="T_5edd6_row17_col1" class="data row17 col1" >16.655241</td>
#       <td id="T_5edd6_row17_col2" class="data row17 col2" >0.767476</td>
#       <td id="T_5edd6_row17_col3" class="data row17 col3" >0.633511</td>
#     </tr>
#   </tbody>
# </table>
# distribution_250
# <style type="text/css">
# #T_ff31b_row0_col0, #T_ff31b_row0_col1, #T_ff31b_row0_col2, #T_ff31b_row0_col3 {
#   color: red;
#   color: red;
#   font-weight: bold;
# }
# #T_ff31b_row3_col0, #T_ff31b_row3_col1, #T_ff31b_row3_col2, #T_ff31b_row3_col3 {
#   color: red;
#   color: red;
# }
# </style>
# <table id="T_ff31b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff31b_level0_col0" class="col_heading level0 col0" >mae</th>
#       <th id="T_ff31b_level0_col1" class="col_heading level0 col1" >rmse</th>
#       <th id="T_ff31b_level0_col2" class="col_heading level0 col2" >spearman</th>
#       <th id="T_ff31b_level0_col3" class="col_heading level0 col3" >r2_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff31b_level0_row0" class="row_heading level0 row0" >modnet_nan_mmf_pgnn_</th>
#       <td id="T_ff31b_row0_col0" class="data row0 col0" >5.248858</td>
#       <td id="T_ff31b_row0_col1" class="data row0 col1" >14.235615</td>
#       <td id="T_ff31b_row0_col2" class="data row0 col2" >0.898054</td>
#       <td id="T_ff31b_row0_col3" class="data row0 col3" >0.683677</td>
#     </tr>
#     <tr>
#       <th id="T_ff31b_level0_row1" class="row_heading level0 row1" >modnet_nan_mmf_</th>
#       <td id="T_ff31b_row1_col0" class="data row1 col0" >5.784565</td>
#       <td id="T_ff31b_row1_col1" class="data row1 col1" >15.741625</td>
#       <td id="T_ff31b_row1_col2" class="data row1 col2" >0.886173</td>
#       <td id="T_ff31b_row1_col3" class="data row1 col3" >0.613209</td>
#     </tr>
#     <tr>
#       <th id="T_ff31b_level0_row2" class="row_heading level0 row2" >modnet_mmf_pgnn_</th>
#       <td id="T_ff31b_row2_col0" class="data row2 col0" >5.765881</td>
#       <td id="T_ff31b_row2_col1" class="data row2 col1" >15.279833</td>
#       <td id="T_ff31b_row2_col2" class="data row2 col2" >0.883553</td>
#       <td id="T_ff31b_row2_col3" class="data row2 col3" >0.635569</td>
#     </tr>
#     <tr>
#       <th id="T_ff31b_level0_row3" class="row_heading level0 row3" >modnet_nan_pgnn_</th>
#       <td id="T_ff31b_row3_col0" class="data row3 col0" >5.604163</td>
#       <td id="T_ff31b_row3_col1" class="data row3 col1" >13.879715</td>
#       <td id="T_ff31b_row3_col2" class="data row3 col2" >0.871287</td>
#       <td id="T_ff31b_row3_col3" class="data row3 col3" >0.699296</td>
#     </tr>
#     <tr>
#       <th id="T_ff31b_level0_row4" class="row_heading level0 row4" >modnet_pgnn_</th>
#       <td id="T_ff31b_row4_col0" class="data row4 col0" >5.817681</td>
#       <td id="T_ff31b_row4_col1" class="data row4 col1" >14.483580</td>
#       <td id="T_ff31b_row4_col2" class="data row4 col2" >0.869175</td>
#       <td id="T_ff31b_row4_col3" class="data row4 col3" >0.672562</td>
#     </tr>
#     <tr>
#       <th id="T_ff31b_level0_row5" class="row_heading level0 row5" >modnet_mmf_</th>
#       <td id="T_ff31b_row5_col0" class="data row5 col0" >5.609491</td>
#       <td id="T_ff31b_row5_col1" class="data row5 col1" >14.656513</td>
#       <td id="T_ff31b_row5_col2" class="data row5 col2" >0.869088</td>
#       <td id="T_ff31b_row5_col3" class="data row5 col3" >0.664696</td>
#     </tr>
#     <tr>
#       <th id="T_ff31b_level0_row6" class="row_heading level0 row6" >et_dflt_pgnn_</th>
#       <td id="T_ff31b_row6_col0" class="data row6 col0" >6.675432</td>
#       <td id="T_ff31b_row6_col1" class="data row6 col1" >15.839602</td>
#       <td id="T_ff31b_row6_col2" class="data row6 col2" >0.849602</td>
#       <td id="T_ff31b_row6_col3" class="data row6 col3" >0.608379</td>
#     </tr>
#     <tr>
#       <th id="T_ff31b_level0_row7" class="row_heading level0 row7" >et_dflt_mmf_pgnn_</th>
#       <td id="T_ff31b_row7_col0" class="data row7 col0" >6.189507</td>
#       <td id="T_ff31b_row7_col1" class="data row7 col1" >15.023034</td>
#       <td id="T_ff31b_row7_col2" class="data row7 col2" >0.844422</td>
#       <td id="T_ff31b_row7_col3" class="data row7 col3" >0.647716</td>
#     </tr>
#     <tr>
#       <th id="T_ff31b_level0_row8" class="row_heading level0 row8" >et_dflt_mmf_</th>
#       <td id="T_ff31b_row8_col0" class="data row8 col0" >6.144405</td>
#       <td id="T_ff31b_row8_col1" class="data row8 col1" >15.278746</td>
#       <td id="T_ff31b_row8_col2" class="data row8 col2" >0.837960</td>
#       <td id="T_ff31b_row8_col3" class="data row8 col3" >0.635621</td>
#     </tr>
#     <tr>
#       <th id="T_ff31b_level0_row9" class="row_heading level0 row9" >lgbm_dflt_mmf_pgnn_</th>
#       <td id="T_ff31b_row9_col0" class="data row9 col0" >6.410858</td>
#       <td id="T_ff31b_row9_col1" class="data row9 col1" >14.737723</td>
#       <td id="T_ff31b_row9_col2" class="data row9 col2" >0.835139</td>
#       <td id="T_ff31b_row9_col3" class="data row9 col3" >0.660970</td>
#     </tr>
#     <tr>
#       <th id="T_ff31b_level0_row10" class="row_heading level0 row10" >et_An_mmf_pgnn_</th>
#       <td id="T_ff31b_row10_col0" class="data row10 col0" >6.630075</td>
#       <td id="T_ff31b_row10_col1" class="data row10 col1" >15.324600</td>
#       <td id="T_ff31b_row10_col2" class="data row10 col2" >0.834100</td>
#       <td id="T_ff31b_row10_col3" class="data row10 col3" >0.633431</td>
#     </tr>
#     <tr>
#       <th id="T_ff31b_level0_row11" class="row_heading level0 row11" >et_An_pgnn_</th>
#       <td id="T_ff31b_row11_col0" class="data row11 col0" >6.823786</td>
#       <td id="T_ff31b_row11_col1" class="data row11 col1" >15.388477</td>
#       <td id="T_ff31b_row11_col2" class="data row11 col2" >0.831295</td>
#       <td id="T_ff31b_row11_col3" class="data row11 col3" >0.630368</td>
#     </tr>
#     <tr>
#       <th id="T_ff31b_level0_row12" class="row_heading level0 row12" >lgbm_dflt_pgnn_</th>
#       <td id="T_ff31b_row12_col0" class="data row12 col0" >6.525860</td>
#       <td id="T_ff31b_row12_col1" class="data row12 col1" >15.106007</td>
#       <td id="T_ff31b_row12_col2" class="data row12 col2" >0.825350</td>
#       <td id="T_ff31b_row12_col3" class="data row12 col3" >0.643814</td>
#     </tr>
#     <tr>
#       <th id="T_ff31b_level0_row13" class="row_heading level0 row13" >lgbm_An_mmf_pgnn_</th>
#       <td id="T_ff31b_row13_col0" class="data row13 col0" >7.016667</td>
#       <td id="T_ff31b_row13_col1" class="data row13 col1" >15.809482</td>
#       <td id="T_ff31b_row13_col2" class="data row13 col2" >0.823383</td>
#       <td id="T_ff31b_row13_col3" class="data row13 col3" >0.609867</td>
#     </tr>
#     <tr>
#       <th id="T_ff31b_level0_row14" class="row_heading level0 row14" >lgbm_An_pgnn_</th>
#       <td id="T_ff31b_row14_col0" class="data row14 col0" >6.817769</td>
#       <td id="T_ff31b_row14_col1" class="data row14 col1" >15.561593</td>
#       <td id="T_ff31b_row14_col2" class="data row14 col2" >0.822469</td>
#       <td id="T_ff31b_row14_col3" class="data row14 col3" >0.622005</td>
#     </tr>
#     <tr>
#       <th id="T_ff31b_level0_row15" class="row_heading level0 row15" >lgbm_dflt_mmf_</th>
#       <td id="T_ff31b_row15_col0" class="data row15 col0" >6.112112</td>
#       <td id="T_ff31b_row15_col1" class="data row15 col1" >14.770501</td>
#       <td id="T_ff31b_row15_col2" class="data row15 col2" >0.819730</td>
#       <td id="T_ff31b_row15_col3" class="data row15 col3" >0.659460</td>
#     </tr>
#     <tr>
#       <th id="T_ff31b_level0_row16" class="row_heading level0 row16" >lgbm_An_mmf_</th>
#       <td id="T_ff31b_row16_col0" class="data row16 col0" >6.596558</td>
#       <td id="T_ff31b_row16_col1" class="data row16 col1" >15.285115</td>
#       <td id="T_ff31b_row16_col2" class="data row16 col2" >0.798749</td>
#       <td id="T_ff31b_row16_col3" class="data row16 col3" >0.635317</td>
#     </tr>
#     <tr>
#       <th id="T_ff31b_level0_row17" class="row_heading level0 row17" >et_An_mmf_</th>
#       <td id="T_ff31b_row17_col0" class="data row17 col0" >6.949693</td>
#       <td id="T_ff31b_row17_col1" class="data row17 col1" >15.245760</td>
#       <td id="T_ff31b_row17_col2" class="data row17 col2" >0.798448</td>
#       <td id="T_ff31b_row17_col3" class="data row17 col3" >0.637193</td>
#     </tr>
#   </tbody>
# </table>
